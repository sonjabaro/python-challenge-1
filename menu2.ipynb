# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Menu dictionary\n",
    "menu = {\n",
    "    \"Snacks\": {\n",
    "        \"Cookie\": .99,\n",
    "        \"Banana\": .69,\n",
    "        \"Apple\": .49,\n",
    "        \"Granola bar\": 1.99\n",
    "    },\n",
    "    \"Meals\": {\n",
    "        \"Burrito\": 4.49,\n",
    "        \"Teriyaki Chicken\": 9.99,\n",
    "        \"Sushi\": 7.49,\n",
    "        \"Pad Thai\": 6.99,\n",
    "        \"Pizza\": {\n",
    "            \"Cheese\": 8.99,\n",
    "            \"Pepperoni\": 10.99,\n",
    "            \"Vegetarian\": 9.99\n",
    "        },\n",
    "        \"Burger\": {\n",
    "            \"Chicken\": 7.49,\n",
    "            \"Beef\": 8.49\n",
    "        }\n",
    "    },\n",
    "    \"Drinks\": {\n",
    "        \"Soda\": {\n",
    "            \"Small\": 1.99,\n",
    "            \"Medium\": 2.49,\n",
    "            \"Large\": 2.99\n",
    "        },\n",
    "        \"Tea\": {\n",
    "            \"Green\": 2.49,\n",
    "            \"Thai iced\": 3.99,\n",
    "            \"Irish breakfast\": 2.49\n",
    "        },\n",
    "        \"Coffee\": {\n",
    "            \"Espresso\": 2.99,\n",
    "            \"Flat white\": 2.99,\n",
    "            \"Iced\": 3.49\n",
    "        }\n",
    "    },\n",
    "    \"Dessert\": {\n",
    "        \"Chocolate lava cake\": 10.99,\n",
    "        \"Cheesecake\": {\n",
    "            \"New York\": 4.99,\n",
    "            \"Strawberry\": 6.49\n",
    "        },\n",
    "        \"Australian Pavlova\": 9.99,\n",
    "        \"Rice pudding\": 4.99,\n",
    "        \"Fried banana\": 4.49\n",
    "    }\n",
    "}\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "\n",
    "# 1. Set up order list. Order list will store a list of dictionaries for\n",
    "# menu item name, item price, and quantity ordered\n",
    "\n",
    "\n",
    "# Launch the store and present a greeting to the customer\n",
    "print(\"Welcome to the variety food truck.\")\n",
    "\n",
    "# Customers may want to order multiple items, so let's create a continuous\n",
    "# loop\n",
    "place_order = True\n",
    "while place_order:\n",
    "    # Ask the customer from which menu category they want to order\n",
    "    print(\"From which menu would you like to order? \")\n",
    "\n",
    "    # Create a variable for the menu item number\n",
    "    i = 1\n",
    "    # Create a dictionary to store the menu for later retrieval\n",
    "    menu_items = {}\n",
    "\n",
    "    # Print the options to choose from menu headings (all the first level\n",
    "    # dictionary items in menu).\n",
    "    for key in menu.keys():\n",
    "        print(f\"{i}: {key}\")\n",
    "        # Store the menu category associated with its menu item number\n",
    "        menu_items[i] = key\n",
    "        # Add 1 to the menu item number\n",
    "        i += 1\n",
    "\n",
    "    # Get the customer's input\n",
    "    menu_category = input(\"Type menu number: \")\n",
    "\n",
    "    # Check if the customer's input is a number\n",
    "    if menu_category.isdigit():\n",
    "        # Check if the customer's input is a valid option\n",
    "        if int(menu_category) in menu_items.keys():\n",
    "            # Save the menu category name to a variable\n",
    "            menu_category_name = menu_items[int(menu_category)]\n",
    "            # Print out the menu category name they selected\n",
    "            print(f\"You selected {menu_category_name}\")\n",
    "\n",
    "            # Print out the menu options from the menu_category_name\n",
    "            print(f\"What {menu_category_name} item would you like to order?\")\n",
    "            i = 1\n",
    "            menu_items = {}\n",
    "            print(\"Item # | Item name                | Price\")\n",
    "            print(\"-------|--------------------------|-------\")\n",
    "            for key, value in menu[menu_category_name].items():\n",
    "                # Check if the menu item is a dictionary to handle differently\n",
    "                if type(value) is dict:\n",
    "                    for key2, value2 in value.items():\n",
    "                        num_item_spaces = 24 - len(key + key2) - 3\n",
    "                        item_spaces = \" \" * num_item_spaces\n",
    "                        print(f\"{i}      | {key} - {key2}{item_spaces} | ${value2}\")\n",
    "                        menu_items[i] = {\n",
    "                            \"Item name\": key + \" - \" + key2,\n",
    "                            \"Price\": value2\n",
    "                        }\n",
    "                        i += 1\n",
    "                else:\n",
    "                    num_item_spaces = 24 - len(key)\n",
    "                    item_spaces = \" \" * num_item_spaces\n",
    "                    print(f\"{i}      | {key}{item_spaces} | ${value}\")\n",
    "                    menu_items[i] = {\n",
    "                        \"Item name\": key,\n",
    "                        \"Price\": value\n",
    "                    }\n",
    "                    i += 1\n",
    "            # 2. Ask customer to input menu item number (standdard input)\n",
    "\n",
    "\n",
    "            # 3. Check if the customer typed a number (isdigit())\n",
    "\n",
    "                # Convert the menu selection to an integer int()\n",
    "\n",
    "\n",
    "                # 4. Check if the menu selection is in the menu items look at the \"keys()\"\n",
    "\n",
    "                    # Store the item name as a variable (How do you get an item from a dictionary?(day3 04))\n",
    "\n",
    "\n",
    "                    # Ask the customer for the quantity of the menu item (input?)\n",
    "\n",
    "\n",
    "                    # Check if the quantity is a number, default to 1 if not(if isdigit())\n",
    "\n",
    "\n",
    "                        # Add the item name, price, and quantity to the order list (append())\n",
    "\n",
    "\n",
    "                        # Tell the customer that their input isn't valid\n",
    "\n",
    "\n",
    "                #   Tell the customer they didn't select a menu option\n",
    "\n",
    "        else:\n",
    "            # Tell the customer they didn't select a menu option\n",
    "            print(f\"{menu_category} was not a menu option.\")\n",
    "    else:\n",
    "        # Tell the customer they didn't select a number\n",
    "        print(\"You didn't select a number.\")\n",
    "\n",
    "    while True:\n",
    "        # Ask the customer if they would like to order anything else\n",
    "        keep_ordering = input(\"Would you like to keep ordering? (Y)es or (N)o \")\n",
    "\n",
    "        # 5. Check the customer's (use match/case here  Day3 activity 02and 3)\n",
    "\n",
    "                # Keep ordering\n",
    "\n",
    "                # Exit the keep ordering question loop\n",
    "\n",
    "                # Complete the order\n",
    "\n",
    "                # Since the customer decided to stop ordering, thank them for\n",
    "                # their order\n",
    "\n",
    "                # Exit the keep ordering question loop\n",
    "\n",
    "\n",
    "                # Tell the customer to try again\n",
    "\n",
    "\n",
    "# Print out the customer's order\n",
    "print(\"This is what we are preparing for you.\\n\")\n",
    "\n",
    "# Uncomment the following line to check the structure of the order\n",
    "#print(order)\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "\n",
    "print(\"Item name                 | Price  | Quantity\")\n",
    "print(\"--------------------------|--------|----------\")\n",
    "\n",
    "# 6. Loop through the items in the customer's order (this is a bit tricky, but here is an example:item_name = order[i][\"Item name\"])\n",
    "\n",
    "    # 7. Store the dictionary items as variables\n",
    "\n",
    "\n",
    "    # 8. Calculate the number of spaces for formatted printing\n",
    "\n",
    "\n",
    "    # 9. Create space strings\n",
    "\n",
    "\n",
    "    # 10. Print the item name, price, and quantity\n",
    "\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "\n",
    "# 11. Calculate the cost of the order using list comprehension\n",
    "# Multiply the price by quantity for each item in the order list, then sum()\n",
    "# and print the prices.  Toughest part, but you can do it!\n"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb Cell 1 line 5
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> {
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a>  "cells": [
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a>   {
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=3'>4</a>    "cell_type": "code",
# ----> <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=4'>5</a>    "execution_count": null,
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=5'>6</a>    "metadata": {},
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=6'>7</a>    "outputs": [],
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=7'>8</a>    "source": [
#       <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=8'>9</a>     "# Menu dictionary\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=9'>10</a>     "menu = {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=10'>11</a>     "    \"Snacks\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=11'>12</a>     "        \"Cookie\": .99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=12'>13</a>     "        \"Banana\": .69,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=13'>14</a>     "        \"Apple\": .49,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=14'>15</a>     "        \"Granola bar\": 1.99\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=15'>16</a>     "    },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=16'>17</a>     "    \"Meals\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=17'>18</a>     "        \"Burrito\": 4.49,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=18'>19</a>     "        \"Teriyaki Chicken\": 9.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=19'>20</a>     "        \"Sushi\": 7.49,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=20'>21</a>     "        \"Pad Thai\": 6.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=21'>22</a>     "        \"Pizza\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=22'>23</a>     "            \"Cheese\": 8.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=23'>24</a>     "            \"Pepperoni\": 10.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=24'>25</a>     "            \"Vegetarian\": 9.99\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a>     "        },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=26'>27</a>     "        \"Burger\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a>     "            \"Chicken\": 7.49,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a>     "            \"Beef\": 8.49\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a>     "        }\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=30'>31</a>     "    },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a>     "    \"Drinks\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     "        \"Soda\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     "            \"Small\": 1.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a>     "            \"Medium\": 2.49,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a>     "            \"Large\": 2.99\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=36'>37</a>     "        },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=37'>38</a>     "        \"Tea\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=38'>39</a>     "            \"Green\": 2.49,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=39'>40</a>     "            \"Thai iced\": 3.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=40'>41</a>     "            \"Irish breakfast\": 2.49\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=41'>42</a>     "        },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=42'>43</a>     "        \"Coffee\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=43'>44</a>     "            \"Espresso\": 2.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=44'>45</a>     "            \"Flat white\": 2.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=45'>46</a>     "            \"Iced\": 3.49\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=46'>47</a>     "        }\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=47'>48</a>     "    },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=48'>49</a>     "    \"Dessert\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=49'>50</a>     "        \"Chocolate lava cake\": 10.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=50'>51</a>     "        \"Cheesecake\": {\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=51'>52</a>     "            \"New York\": 4.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=52'>53</a>     "            \"Strawberry\": 6.49\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=53'>54</a>     "        },\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=54'>55</a>     "        \"Australian Pavlova\": 9.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=55'>56</a>     "        \"Rice pudding\": 4.99,\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=56'>57</a>     "        \"Fried banana\": 4.49\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=57'>58</a>     "    }\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=58'>59</a>     "}\n"
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=59'>60</a>    ]
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=60'>61</a>   },
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=61'>62</a>   {
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=62'>63</a>    "cell_type": "code",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=63'>64</a>    "execution_count": null,
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=64'>65</a>    "metadata": {},
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=65'>66</a>    "outputs": [],
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=66'>67</a>    "source": [
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=67'>68</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=68'>69</a>     "# 1. Set up order list. Order list will store a list of dictionaries for\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=69'>70</a>     "# menu item name, item price, and quantity ordered\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=70'>71</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=71'>72</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=72'>73</a>     "# Launch the store and present a greeting to the customer\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=73'>74</a>     "print(\"Welcome to the variety food truck.\")\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=74'>75</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=75'>76</a>     "# Customers may want to order multiple items, so let's create a continuous\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=76'>77</a>     "# loop\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=77'>78</a>     "place_order = True\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=78'>79</a>     "while place_order:\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=79'>80</a>     "    # Ask the customer from which menu category they want to order\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=80'>81</a>     "    print(\"From which menu would you like to order? \")\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=81'>82</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=82'>83</a>     "    # Create a variable for the menu item number\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=83'>84</a>     "    i = 1\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=84'>85</a>     "    # Create a dictionary to store the menu for later retrieval\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=85'>86</a>     "    menu_items = {}\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=86'>87</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=87'>88</a>     "    # Print the options to choose from menu headings (all the first level\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=88'>89</a>     "    # dictionary items in menu).\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=89'>90</a>     "    for key in menu.keys():\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=90'>91</a>     "        print(f\"{i}: {key}\")\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=91'>92</a>     "        # Store the menu category associated with its menu item number\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=92'>93</a>     "        menu_items[i] = key\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=93'>94</a>     "        # Add 1 to the menu item number\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=94'>95</a>     "        i += 1\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=95'>96</a>     "\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=96'>97</a>     "    # Get the customer's input\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=97'>98</a>     "    menu_category = input(\"Type menu number: \")\n",
#      <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=98'>99</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=99'>100</a>     "    # Check if the customer's input is a number\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=100'>101</a>     "    if menu_category.isdigit():\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=101'>102</a>     "        # Check if the customer's input is a valid option\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=102'>103</a>     "        if int(menu_category) in menu_items.keys():\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=103'>104</a>     "            # Save the menu category name to a variable\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=104'>105</a>     "            menu_category_name = menu_items[int(menu_category)]\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=105'>106</a>     "            # Print out the menu category name they selected\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=106'>107</a>     "            print(f\"You selected {menu_category_name}\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=107'>108</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=108'>109</a>     "            # Print out the menu options from the menu_category_name\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=109'>110</a>     "            print(f\"What {menu_category_name} item would you like to order?\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=110'>111</a>     "            i = 1\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=111'>112</a>     "            menu_items = {}\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=112'>113</a>     "            print(\"Item # | Item name                | Price\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=113'>114</a>     "            print(\"-------|--------------------------|-------\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=114'>115</a>     "            for key, value in menu[menu_category_name].items():\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=115'>116</a>     "                # Check if the menu item is a dictionary to handle differently\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=116'>117</a>     "                if type(value) is dict:\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=117'>118</a>     "                    for key2, value2 in value.items():\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=118'>119</a>     "                        num_item_spaces = 24 - len(key + key2) - 3\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=119'>120</a>     "                        item_spaces = \" \" * num_item_spaces\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=120'>121</a>     "                        print(f\"{i}      | {key} - {key2}{item_spaces} | ${value2}\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=121'>122</a>     "                        menu_items[i] = {\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=122'>123</a>     "                            \"Item name\": key + \" - \" + key2,\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=123'>124</a>     "                            \"Price\": value2\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=124'>125</a>     "                        }\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=125'>126</a>     "                        i += 1\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=126'>127</a>     "                else:\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=127'>128</a>     "                    num_item_spaces = 24 - len(key)\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=128'>129</a>     "                    item_spaces = \" \" * num_item_spaces\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=129'>130</a>     "                    print(f\"{i}      | {key}{item_spaces} | ${value}\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=130'>131</a>     "                    menu_items[i] = {\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=131'>132</a>     "                        \"Item name\": key,\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=132'>133</a>     "                        \"Price\": value\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=133'>134</a>     "                    }\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=134'>135</a>     "                    i += 1\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=135'>136</a>     "            # 2. Ask customer to input menu item number (standdard input)\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=136'>137</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=137'>138</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=138'>139</a>     "            # 3. Check if the customer typed a number (isdigit())\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=139'>140</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=140'>141</a>     "                # Convert the menu selection to an integer int()\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=141'>142</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=142'>143</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=143'>144</a>     "                # 4. Check if the menu selection is in the menu items look at the \"keys()\"\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=144'>145</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=145'>146</a>     "                    # Store the item name as a variable (How do you get an item from a dictionary?(day3 04))\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=146'>147</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=147'>148</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=148'>149</a>     "                    # Ask the customer for the quantity of the menu item (input?)\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=149'>150</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=150'>151</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=151'>152</a>     "                    # Check if the quantity is a number, default to 1 if not(if isdigit())\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=152'>153</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=153'>154</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=154'>155</a>     "                        # Add the item name, price, and quantity to the order list (append())\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=155'>156</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=156'>157</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=157'>158</a>     "                        # Tell the customer that their input isn't valid\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=158'>159</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=159'>160</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=160'>161</a>     "                #   Tell the customer they didn't select a menu option\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=161'>162</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=162'>163</a>     "        else:\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=163'>164</a>     "            # Tell the customer they didn't select a menu option\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=164'>165</a>     "            print(f\"{menu_category} was not a menu option.\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=165'>166</a>     "    else:\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=166'>167</a>     "        # Tell the customer they didn't select a number\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=167'>168</a>     "        print(\"You didn't select a number.\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=168'>169</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=169'>170</a>     "    while True:\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=170'>171</a>     "        # Ask the customer if they would like to order anything else\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=171'>172</a>     "        keep_ordering = input(\"Would you like to keep ordering? (Y)es or (N)o \")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=172'>173</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=173'>174</a>     "        # 5. Check the customer's (use match/case here  Day3 activity 02and 3)\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=174'>175</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=175'>176</a>     "                # Keep ordering\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=176'>177</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=177'>178</a>     "                # Exit the keep ordering question loop\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=178'>179</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=179'>180</a>     "                # Complete the order\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=180'>181</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=181'>182</a>     "                # Since the customer decided to stop ordering, thank them for\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=182'>183</a>     "                # their order\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=183'>184</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=184'>185</a>     "                # Exit the keep ordering question loop\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=185'>186</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=186'>187</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=187'>188</a>     "                # Tell the customer to try again\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=188'>189</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=189'>190</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=190'>191</a>     "# Print out the customer's order\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=191'>192</a>     "print(\"This is what we are preparing for you.\\n\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=192'>193</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=193'>194</a>     "# Uncomment the following line to check the structure of the order\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=194'>195</a>     "#print(order)\n"
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=195'>196</a>    ]
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=196'>197</a>   },
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=197'>198</a>   {
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=198'>199</a>    "cell_type": "code",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=199'>200</a>    "execution_count": null,
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=200'>201</a>    "metadata": {},
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=201'>202</a>    "outputs": [],
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=202'>203</a>    "source": [
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=203'>204</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=204'>205</a>     "print(\"Item name                 | Price  | Quantity\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=205'>206</a>     "print(\"--------------------------|--------|----------\")\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=206'>207</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=207'>208</a>     "# 6. Loop through the items in the customer's order (this is a bit tricky, but here is an example:item_name = order[i][\"Item name\"])\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=208'>209</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=209'>210</a>     "    # 7. Store the dictionary items as variables\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=210'>211</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=211'>212</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=212'>213</a>     "    # 8. Calculate the number of spaces for formatted printing\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=213'>214</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=214'>215</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=215'>216</a>     "    # 9. Create space strings\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=216'>217</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=217'>218</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=218'>219</a>     "    # 10. Print the item name, price, and quantity\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=219'>220</a>     "\n"
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=220'>221</a>    ]
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=221'>222</a>   },
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=222'>223</a>   {
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=223'>224</a>    "cell_type": "code",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=224'>225</a>    "execution_count": null,
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=225'>226</a>    "metadata": {},
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=226'>227</a>    "outputs": [],
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=227'>228</a>    "source": [
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=228'>229</a>     "\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=229'>230</a>     "# 11. Calculate the cost of the order using list comprehension\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=230'>231</a>     "# Multiply the price by quantity for each item in the order list, then sum()\n",
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=231'>232</a>     "# and print the prices.  Toughest part, but you can do it!\n"
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=232'>233</a>    ]
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=233'>234</a>   }
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=234'>235</a>  ],
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=235'>236</a>  "metadata": {
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=236'>237</a>   "language_info": {
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=237'>238</a>    "name": "python"
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=238'>239</a>   }
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=239'>240</a>  },
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=240'>241</a>  "nbformat": 4,
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=241'>242</a>  "nbformat_minor": 2
#     <a href='vscode-notebook-cell:/Users/sonjambaro/Desktop/classdata/Week_2_Challenge/python-challenge-1/menu2.ipynb#W0sZmlsZQ%3D%3D?line=242'>243</a> }
#
# NameError: name 'null' is not defined
